# %% [markdown]
# <a href="https://colab.research.google.com/github/Alok942563/APS_Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph_input_str = input("Please enter the graph as a Python dictionary string (e.g., {'A': {'B': 4, 'C': 2}, 'B': {'A': 4, 'C': 5, 'D': 10}}): ")

try:
    graph = eval(graph_input_str)
    # Basic validation for the graph structure
    if not isinstance(graph, dict) or not all(isinstance(v, dict) for v in graph.values()):
        raise ValueError("Invalid graph format. Please ensure it's a dictionary of dictionaries.")

    start_node = input("Please enter the start node (e.g., 'A'): ")
    if start_node not in graph:
        raise ValueError(f"Start node '{start_node}' not found in the graph.")

    result = dijkstra(graph, start_node)

    print(f"\nShortest distances from node {start_node}:")
    for node in result:
        print(f"Distance from {start_node} to {node} = {result[node]}")

except Exception as e:
    print(f"Error processing input: {e}")
    print("Please ensure your graph input is a valid Python dictionary string and the start node exists in the graph.")

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.
